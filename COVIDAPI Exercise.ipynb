# %% [markdown]
# #Exercise
# Goal: From the API data, pull the 5 countries with the highest count of confirmed cases.

# %%
#Install and import packages
# !pip install requests
# !pip install json
# !pip install pandas
import requests
import json
import pandas

# %%
#store json data into python object
response = requests.get('https://api.covid19api.com/summary').json()

# %%
#Create empty lists to store desired information
country = []
cases = []

# %%
#Extract country name, confirmed cases. 
#Input the answers.
for i in response[]:
    country.append(i[])
    cases.append(i[])

# %%
#Place into dataframe. 
data = pandas.DataFrame({
    'Country': country,
    'cases': cases
})
display(data)

# %% [markdown]
# How do we get the top 5?
